fig.add_trace(go.Scatter(x=x, y=y2, mode='lines', name='Smooth Signal',
                         line=dict(color='red', width=5)))

for x_val in [50, 100, 150, 200]:
    fig.add_shape(type="line",
                  x0=x_val, x1=x_val, y0=-2, y1=-1.95,
                  line=dict(color="black", width=2, dash="solid"))
    fig.add_shape(type="line",
                  x0=x_val, x1=x_val, y0=1.95, y1=2,
                  line=dict(color="black", width=2, dash="solid"))

for y_val in [-1.5, -1, -0.5, 0, 0.5, 1, 1.5]:
    fig.add_shape(type="line",
                  x0=0, x1=2, y0=y_val, y1=y_val,
                  line=dict(color="black", width=2, dash="solid"))
    fig.add_shape(type="line",
                  x0=208, x1=210, y0=y_val, y1=y_val,
                  line=dict(color="black", width=2, dash="solid"))

# Add border using shapes
border_lines = [
    dict(type="line", x0=0, x1=210, y0=-2, y1=-2, line=dict(color="black", width=4)),
    dict(type="line", x0=0, x1=210, y0=2, y1=2, line=dict(color="black", width=4)),
    dict(type="line", x0=0, x1=0, y0=-2, y1=2, line=dict(color="black", width=4)),
    dict(type="line", x0=210, x1=210, y0=-2, y1=2, line=dict(color="black", width=4))
]

for line in border_lines:
    fig.add_shape(**line)

# Styling the layout
fig.update_layout(
    xaxis_title="Time",
    yaxis_title="Potiential Values",
    xaxis=dict(showgrid=True, gridwidth=2, gridcolor='#ddd', zeroline=False, range=[0, 210]),
    yaxis=dict(showgrid=True, gridwidth=2, gridcolor='#ddd', zeroline=False, range=[-2, 2]),
    plot_bgcolor='white',
    paper_bgcolor="white",
    showlegend=True,
    width=1600,   # Setting width to 600
    height=1200,   # Setting height to 600
    legend=dict(
        x=0.02,
        y=0.97,
        traceorder="normal",
        font=dict(
            family="Courier New, monospace",
            size=24,
            color="#000"
        ),
        bgcolor="White",
        bordercolor="Black",
        borderwidth=2
    ),
    margin=dict(l=50, r=50, b=50, t=50),
    font=dict(
        family="Courier New, monospace",
        size=28,
        color="black"
    ),
)

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
ONLY_ECG = [0.9974,
0.8603,
0.7761,
0.995,
0.9791,
0.9906,
0.9473,
0.8,
0.9756,
0.7164]

WITH_META_DATA = [0.9974,
0.8922,
0.8531,
0.9981,
0.9868,
0.9923,
0.9685,
0.7692,
1,
0.7636]

# %%
import plotly.graph_objects as go
x = [i+0.5 for i in range(10)]

# Create the figure
fig = go.Figure()
NAME = ['/', "A",  'F', 'L', 'N', 'R', 'V', 'a', 'f', 'j']
# Add scatter points for each model
fig.add_trace(go.Scatter(x=x, y=ONLY_ECG, mode='lines+markers', name='Only ECG',
                         line=dict(color='blue', width=5),
                        marker=dict(size=15, color='blue')))
fig.add_trace(go.Scatter(x=x, y=WITH_META_DATA, mode='lines+markers', name='With Patient Characterstics',
                         line=dict(color='red', width=5),
                        marker=dict(size=15, color='red')))

for x_val in x:
    fig.add_shape(type="line",
                  x0=x_val, x1=x_val, y0=0.7, y1=-0.8,
                  line=dict(color="black", width=2, dash="solid"))
    fig.add_shape(type="line",
                  x0=x_val, x1=x_val, y0=1.02, y1=1.01,
                  line=dict(color="black", width=2, dash="solid"))

for y_val in [0.75, 0.8, 0.85, 0.9, 0.95, 1]:
    fig.add_shape(type="line",
                  x0=0, x1=0.2, y0=y_val, y1=y_val,
                  line=dict(color="black", width=2, dash="solid"))
    fig.add_shape(type="line",
                  x0=9.8, x1=10, y0=y_val, y1=y_val,
                  line=dict(color="black", width=2, dash="solid"))

# Add border using shapes
border_lines = [
    dict(type="line", x0=0, x1=10, y0=0.7, y1=0.7, line=dict(color="black", width=4)),
    dict(type="line", x0=0, x1=10, y0=1.02, y1=1.02, line=dict(color="black", width=4)),
    dict(type="line", x0=0, x1=0, y0=0.7, y1=1.02, line=dict(color="black", width=4)),
    dict(type="line", x0=10, x1=10, y0=0.7, y1=1.02, line=dict(color="black", width=4))
]

for line in border_lines:
    fig.add_shape(**line)

# Styling the layout
fig.update_layout(
    xaxis_title="Arrhythmia",
    yaxis_title="F1-Score",
    xaxis=dict(showgrid=True, gridwidth=2, gridcolor='#ddd', zeroline=False, range=[0,10], tickvals=x,
        ticktext=NAME),
    yaxis=dict(showgrid=True, gridwidth=2, gridcolor='#ddd', zeroline=False, range=[0.7, 1.02]),
    plot_bgcolor='white',
    paper_bgcolor="white",
    showlegend=True,
    width=1600,   # Setting width to 600
    height=900,   # Setting height to 600
    legend=dict(
        x=0.02,
        y=0.03,
        traceorder="normal",
        font=dict(
            family="Courier New, monospace",
            size=24,
            color="#000"
        ),
        bgcolor="White",
        bordercolor="Black",
        borderwidth=2
    ),
    margin=dict(l=50, r=50, b=50, t=50),
    font=dict(
        family="Courier New, monospace",
        size=28,
        color="black"
    ),
)

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go

x = [453666, 4061798, 3238538, 23601930]
y = [82745124, 252834736,366071868, 2470895676]
models = ["DPN-SACC", "EfficientNetB0", "MobileNet", ""]
symbols = ["diamond", "triangle-up", "star", "circle"]

# Create the figure
fig = go.Figure()

# Add scatter points for each model
for i, model in enumerate(models):
    fig.add_trace(go.Scatter(x=[x[i]], y=[y[i]], mode='markers+text',
                             marker=dict(size=10, symbol=symbols[i]),
                             text=model,
                             textposition="top right",
                             name=model))



# Styling the layout
fig.update_layout(
    xaxis_title="Total Paramaters",
    yaxis_title="FLOPs",
    xaxis=dict(showgrid=True, gridwidth=2, gridcolor='#ddd', zeroline=False),
    yaxis=dict(showgrid=True, gridwidth=2, gridcolor='#ddd', zeroline=False),
    plot_bgcolor='white',
    paper_bgcolor="white",
    showlegend=False,
    width=1400,   # Setting width to 600
    height=1000,   # Setting height to 600
    legend=dict(
        x=0.02,
        y=0.03,
        traceorder="normal",
        font=dict(
            family="Courier New, monospace",
            size=24,
            color="#000"
        ),
        bgcolor="White",
        bordercolor="Black",
        borderwidth=2
    ),
    margin=dict(l=50, r=50, b=50, t=50),
    font=dict(
        family="Courier New, monospace",
        size=40,
        color="black"
    ),
)

fig.update_xaxes(type="log")
fig.update_yaxes(type="log")

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go

x = [39, 79, 32, 75]
y = [x for x in [0.440048, 0.910327, 0.681555, 1.61959]]
models = ["DPN-SACC", "", "MobileNet", "ResNet50"]
symbols = ["diamond", "triangle-up", "star", "circle"]

# Create the figure
fig = go.Figure()

# Add scatter points for each model
for i, model in enumerate(models):
    fig.add_trace(go.Scatter(x=[x[i]], y=[y[i]], mode='markers+text',
                             marker=dict(size=10, symbol=symbols[i]),
                             text=model,
                             textposition="top right",
                             name=model))



# Styling the layout
fig.update_layout(
    xaxis_title="Training Time (step/ms)",
    yaxis_title="Memory Requirement (GB)",
    xaxis=dict(showgrid=True, gridwidth=2, gridcolor='#ddd', zeroline=False, range=[25,85]),
    yaxis=dict(showgrid=True, gridwidth=2, gridcolor='#ddd', zeroline=False, range=[0.3,1.7]),
    plot_bgcolor='white',
    paper_bgcolor="white",
    showlegend=False,
    width=1400,   # Setting width to 600
    height=1000,   # Setting height to 600
    legend=dict(
        x=0.02,
        y=0.03,
        traceorder="normal",
        font=dict(
            family="Courier New, monospace",
            size=24,
            color="#000"
        ),
        bgcolor="White",
        bordercolor="Black",
        borderwidth=2
    ),
    margin=dict(l=50, r=50, b=50, t=50),
    font=dict(
        family="Courier New, monospace",
        size=40,
        color="black"
    ),
)


# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
